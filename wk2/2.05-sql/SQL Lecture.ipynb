# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgres://opexfclopritrp:4ef93ab4cbaa8ad1f21cfad2b47a6554b54cef14ec20d2884739e7f1b023ce26@ec2-174-129-37-15.compute-1.amazonaws.com:5432/d25ivq51vhhbqk')
#engine = create_engine('postgres://ufjar3dimvcpta:pd3f3a35be39763c5ce1f2e31dc2b8dc28fdee3c14b1c7a2bd91b653f14037cff@ec2-54-89-181-194.compute-1.amazonaws.com:5432/d2ous5sgh041bh')

# %%
#Some French Waiters Grow Healthy Orange Limes

#sql = """
#SELECT name, calories
#FROM foods
#"""

#sql = """
#SELECT f.name AS food, f.calories
#FROM foods AS f
#"""

#sql = """
#SELECT name AS cats
#FROM categories AS foodstuff
#"""

#sql = """
#SELECT *
#FROM foods
#WHERE calories > 100
#ORDER BY calories ASC
#LIMIT 10
#"""

#sql = '''
#SELECT *
#FROM foods
#WHERE calories > 1000 AND carbs < 30
#'''

#sql = '''
#SELECT *
#FROM restaurants
#WHERE name = 'McDonald''s'
#'''

#sql = '''
#SELECT *
#FROM foods
#WHERE name ILIKE '%%steak%%'
#'''

#sql = '''
#SELECT r.name AS Restaurants, f.name AS Foods
#FROM restaurants AS r
#INNER JOIN foods AS f ON f.restaurant_id = r.id
#'''

#sql = '''
#SELECT r.name AS Restaurants, f.calories AS calories, f.name AS Foods
#FROM restaurants AS r
#INNER JOIN foods AS f ON f.restaurant_id = r.id
#WHERE r.name ILIKE 'Burger King'
#'''

#sql = '''
#SELECT r.name AS Restaurants, f.calories AS calories, f.name AS Foods
#FROM restaurants AS r
#INNER JOIN foods AS f ON f.restaurant_id = r.id
#WHERE r.name ILIKE 'Jimmy John%%' AND f.calories > 700
#'''

#sql = '''
#SELECT r.name AS Restaurants, f.calories AS calories, f.name AS Foods
#FROM restaurants AS r
#INNER JOIN foods AS f ON f.restaurant_id = r.id
#WHERE (r.name ILIKE 'Chili%%' OR r.name ILIKE '%%outback%%') AND f.name ILIKE '%%steak%%'
#'''

#sql = '''
#SELECT *
#FROM restaurants as r
#INNER JOIN foods as f ON f.restaurant_id = r.id
#WHERE r.name ILIKE '%%outback%%'
#'''

#sql = '''
#SELECT foods.name, categories.name as category
#FROM foods
#INNER JOIN categories_foods ON categories_foods.food_id = foods.id
#INNER JOIN categories ON categories_foods.category_id = categories.id
#'''

#sql = '''
#SELECT foods.name, categories.name as category
#FROM categories
#INNER JOIN categories_foods ON categories.id = categories_foods.category_id
#INNER JOIN foods ON foods.id = categories_foods.food_id
#'''

#sql = '''
#SELECT foods.name, categories.name as category
#FROM categories
#INNER JOIN categories_foods ON categories.id = categories_foods.category_id
#INNER JOIN foods ON foods.id = categories_foods.food_id
#WHERE foods.name ILIKE '%%burger%%'
#'''

#sql = '''
#SELECT foods.name AS food, restaurants.name AS restaurant, categories.name as category
#FROM foods
#INNER JOIN restaurants ON restaurants.id = foods.restaurant_id
#INNER JOIN categories_foods ON categories_foods.food_id = foods.id
#INNER JOIN categories ON categories.id = categories_foods.category_id
#'''

#sql = '''
#SELECT restaurants.name, AVG(foods.calories) as avg_cals
#FROM restaurants
#INNER JOIN foods ON foods.restaurant_id = restaurants.id
#GROUP BY restaurants.name
#HAVING AVG(foods.calories) > 500
#ORDER BY AVG(foods.calories) DESC
#'''

sql = '''
SELECT restaurants.name, AVG(foods.calories) as avg_cals
FROM restaurants
INNER JOIN foods ON foods.restaurant_id = restaurants.id
GROUP BY restaurants.name
HAVING AVG(foods.calories) > 500
ORDER BY AVG(foods.calories) DESC
'''

df = pd.read_sql_query(sql, engine)
df
# Out:
#                                      name    avg_cals
# 0                        Joe's Crab Shack  841.404959
# 1   Bojangle's Famous Chicken 'n Biscuits  745.068493
# 2                                 Chili's  718.771429
# 3                              Applebee's  679.355000
# 4                                 Quiznos  678.137255
# 5             Five Guys Burgers and Fries  662.000000
# 6                                    IHOP  607.850000
# 7                      Buffalo Wild Wings  574.229358
# 8               Red Robin Gourmet Burgers  574.145000
# 9                            Olive Garden  570.384615
# 10                            Dairy Queen  565.925000
# 11                Romano's Macaroni Grill  562.837838
# 12                                   FATZ  542.320000
# 13                     Outback Steakhouse  535.424658
# 14                               Fazoli's  534.728261
# 15                            O'Charley's  531.428571
# ...

# %%
sql = """
SELECT *
FROM restaurants
"""


df = pd.read_sql_query(sql, engine)
df
# Out:
#   File "<ipython-input-15-08fa9d0db0d3>", line 6
#     pd.set_option('max_rows'=5000)
#                  ^
# SyntaxError: keyword can't be an expression

# %%
sql = """
SELECT r.name AS Restaurants, f.name AS Foods
FROM restaurants AS r
INNER JOIN foods AS f ON f.restaurant_id = r.id
"""

pd.set_option('display.max_rows',5000)
df = pd.read_sql_query(sql, engine)
df
# Out:
#                                 restaurants  \
# 0                           A&W Restaurants
# 1                           A&W Restaurants
# 2                           A&W Restaurants
# 3                           A&W Restaurants
# 4                           A&W Restaurants
# 5                           A&W Restaurants
# 6                           A&W Restaurants
# 7                           A&W Restaurants
# 8                           A&W Restaurants
# 9                           A&W Restaurants
# 10                          A&W Restaurants
# 11                          A&W Restaurants
# 12                          A&W Restaurants
# 13                          A&W Restaurants
# 14                          A&W Restaurants
# 15                          A&W Restaurants
# 16                          A&W Restaurants
# 17                          A&W Restaurants
# 18                          A&W Restaurants
# 19                          A&W Restaurants
# ...
